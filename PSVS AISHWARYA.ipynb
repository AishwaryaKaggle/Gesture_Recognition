# %% [markdown]
# #  P.S.V.S.AISHWARYA

# %% [markdown]
# #Importing the Libraries

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os

# %% [markdown]
# #Setting Random Seed

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow import keras
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# #Reading Train.csv and Test.csv

# %%
train_doc = np.random.permutation(open('/home/datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/home/datasets/Project_data/val.csv').readlines())
batch_size = 8 #experiment with the batch size

# %% [markdown]
# #Setting the image_height and image_width

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 100
image_width = 100
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int) #create a list of image numbers you want to use for a particular video

# %% [markdown]
# #Resizing the Image

# %%
from skimage.io import imread
from skimage.transform import resize

def resize_crop_image(image):
    if image.shape[0] > 120 and image.shape[1] > 120:
        image = resize(image, (120, 120))
        
    height = image.shape[0]
    width = image.shape[1]
    height_center = height//2
    width_center = width//2
    image = image[(height_center-60):(height_center+70), (width_center-50):(width_center+70)]
    image = resize(image,(image_height, image_width))
    return image

# %% [markdown]
# #Image Plotting Code

# %%
from matplotlib import pyplot as plt

def show_resize_crop_image(paths):

    for index, path in enumerate(paths):
        plt.figure(figsize=(20,20))
            
        plt.subplot(5, 2, index*2+1)
        image = resize_crop_image(imread(path))
        plt.imshow(image)
        plt.title('Modified')
        
        plt.subplot(5, 2, index*2+2)
        plt.imshow(imread(path))
        plt.title('Original')
                
    plt.show()

# %%
paths = ["/home/datasets/Project_data/train/WIN_20180907_15_53_00_Pro_Thumbs Down_new/WIN_20180907_15_53_00_Pro_00001.png",
        "/home/datasets/Project_data/train/WIN_20180907_15_56_38_Pro_Right Swipe_new/WIN_20180907_15_56_38_Pro_00013.png",
        "/home/datasets/Project_data/train/WIN_20180925_17_22_32_Pro_Right_Swipe_new/WIN_20180925_17_22_32_Pro_00009.png",
        "/home/datasets/Project_data/train/WIN_20180907_15_53_12_Pro_Thumbs Up_new/WIN_20180907_15_53_12_Pro_00011.png"]

show_resize_crop_image(paths)

# %% [markdown]
# #Generator Code

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size, len(img_idx), image_height, image_width, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, gestures)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    image = resize_crop_image(image)
                                         
                    batch_data[folder,idx,:,:,0] = image[:,:,0] #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = image[:,:,1] #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = image[:,:,2] #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size * num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            
            for batch in range(batch_size): # we iterate over the number of batches
                batch_data = np.zeros((batch_size, len(img_idx), image_height, image_width, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
                batch_labels = np.zeros((batch_size, gestures)) # batch_labels is the one hot representation of the output
                for folder in range(batch_size): # iterate over the batch_size
                    imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                    for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                        image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                        #crop the images and resize them. Note that the images are of 2 different shape 
                        #and the conv3D will throw error if the inputs in a batch have different shapes
                        image = resize_crop_image(image)
                                         
                        batch_data[folder,idx,:,:,0] = image[:,:,0] #normalise and feed in the image
                        batch_data[folder,idx,:,:,1] = image[:,:,1] #normalise and feed in the image
                        batch_data[folder,idx,:,:,2] = image[:,:,2] #normalise and feed in the image
                    
                    batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
                yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/home/datasets/Project_data/train'
val_path = '/home/datasets/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 25

# %% [markdown]
# MODEL WITH CONV3D

# %% [markdown]
#  MODEL WITH CONV3D EXPERIMENT-1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation, Conv3D, MaxPooling3D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import optimizers

#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

# %%
optimiser = optimizers.SGD(learning_rate=0.001, decay=1e-6, momentum=0.7, nesterov=True) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 15, 100, 100, 8)   656
#
#  batch_normalization_13 (Bat  (None, 15, 100, 100, 8)  32
#  chNormalization)
#
#  activation_12 (Activation)  (None, 15, 100, 100, 8)   0
#
#  max_pooling3d_12 (MaxPoolin  (None, 7, 50, 50, 8)     0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 7, 50, 50, 16)     3472
#
#  batch_normalization_14 (Bat  (None, 7, 50, 50, 16)    64
#  chNormalization)
#
#  activation_13 (Activation)  (None, 7, 50, 50, 16)     0
#
#  max_pooling3d_13 (MaxPoolin  (None, 3, 25, 25, 16)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 3, 25, 25, 32)     13856
#
#  batch_normalization_15 (Bat  (None, 3, 25, 25, 32)    128
#  chNormalization)
#
#  activation_14 (Activation)  (None, 3, 25, 25, 32)     0
#
#  max_pooling3d_14 (MaxPoolin  (None, 1, 12, 12, 32)    0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 4608)              0
#
#  dense_15 (Dense)            (None, 64)                294976
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 317,669
# Trainable params: 317,557
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, 4)
val_generator = generator(val_path, val_doc, 4)

# %%
model_name = 'model_init_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/4)
else:
    steps_per_epoch = (num_train_sequences//4) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/4)
else:
    validation_steps = (num_val_sequences//4) + 1

# %% [markdown]
# Fitting The MODEL

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=10, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/10
# 67/67 [==============================] - ETA: 0s - loss: 1.6070 - categorical_accuracy: 0.1741
# Epoch 00001: val_loss did not improve from 1.57956
# 67/67 [==============================] - 104s 2s/step - loss: 1.6070 - categorical_accuracy: 0.1741 - val_loss: 1.6069 - val_categorical_accuracy: 0.2250 - lr: 2.5000e-04
# Epoch 2/10
# 67/67 [==============================] - ETA: 0s - loss: 1.6108 - categorical_accuracy: 0.1791
# Epoch 00002: val_loss did not improve from 1.57956
# 67/67 [==============================] - 103s 2s/step - loss: 1.6108 - categorical_accuracy: 0.1791 - val_loss: 1.5952 - val_categorical_accuracy: 0.2750 - lr: 2.5000e-04
# Epoch 3/10
# 67/67 [==============================] - ETA: 0s - loss: 1.5985 - categorical_accuracy: 0.2587
# Epoch 00003: val_loss did not improve from 1.57956
# 67/67 [==============================] - 99s 1s/step - loss: 1.5985 - categorical_accuracy: 0.2587 - val_loss: 1.5958 - val_categorical_accuracy: 0.2000 - lr: 2.5000e-04
# Epoch 4/10
# 67/67 [==============================] - ETA: 0s - loss: 1.5860 - categorical_accuracy: 0.2289
# Epoch 00005: val_loss did not improve from 1.57956
# 67/67 [==============================] - 104s 2s/step - loss: 1.5860 - categorical_accuracy: 0.2289 - val_loss: 1.5892 - val_categorical_accuracy: 0.2000 - lr: 1.2500e-04
# Epoch 6/10
# 67/67 [==============================] - ETA: 0s - loss: 1.6065 - categorical_accuracy: 0.2040
# Epoch 00006: val_loss did not improve from 1.57956
# 67/67 [==============================] - 102s 2s/step - loss: 1.6065 - categorical_accuracy: 0.2040 - val_loss: 1.5929 - val_categorical_accuracy: 0.1750 - lr: 1.2500e-04
# Epoch 7/10
# 67/67 [==============================] - ETA: 0s - loss: 1.6116 - categorical_accuracy: 0.2189
# Epoch 00007: val_loss did not improve from 1.57956
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 [==============================] - 106s 2s/step - loss: 1.6116 - categorical_accuracy: 0.2189 - val_loss: 1.5976 - val_categorical_accuracy: 0.2250 - lr: 1.2500e-04
# Epoch 8/10
# 67/67 [==============================] - ETA: 0s - loss: 1.5957 - categorical_accuracy: 0.2836
# Epoch 00008: val_loss did not improve from 1.57956
# 67/67 [==============================] - 100s 1s/step - loss: 1.5957 - categorical_accuracy: 0.2836 - val_loss: 1.5913 - val_categorical_accuracy: 0.2250 - lr: 6.2500e-05
# Epoch 9/10
# 67/67 [==============================] - ETA: 0s - loss: 1.6008 - categorical_accuracy: 0.2289
# Epoch 00009: val_loss did not improve from 1.57956
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 [==============================] - 99s 1s/step - loss: 1.6008 - categorical_accuracy: 0.2289 - val_loss: 1.6019 - val_categorical_accuracy: 0.2250 - lr: 6.2500e-05
# Epoch 10/10
# 67/67 [==============================] - ETA: 0s - loss: 1.6055 - categorical_accuracy: 0.2338
# Epoch 00010: val_loss did not improve from 1.57956
# 67/67 [==============================] - 100s 1s/step - loss: 1.6055 - categorical_accuracy: 0.2338 - val_loss: 1.5896 - val_categorical_accuracy: 0.3000 - lr: 3.1250e-05

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][10-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][10-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])

    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(10)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

plot_history(history)
# Out:
# **Training Accuracy:** 0.23%
# **Validation Accuracy:** 0.3%

# %% [markdown]
# MODEL WITH CONV3D EXPERIMENT-2

# %%
from matplotlib import pyplot as plt

def show_resize_crop_image(paths):

    for index, path in enumerate(paths):
        plt.figure(figsize=(20,20))
            
        plt.subplot(5, 2, index*2+1)
        image = resize_crop_image(imread(path))
        plt.imshow(image)
        plt.title('Modified')
        
        plt.subplot(5, 2, index*2+2)
        plt.imshow(imread(path))
        plt.title('Original')
                
    plt.show()

# %% [markdown]
# REDUCING THE SIZE OF IMAGE FROM 100 TO 50

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)

num_epochs=25

show_resize_crop_image(paths)

# %%
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

# %%
optimiser = optimizers.SGD(learning_rate=0.001, decay=1e-6, momentum=0.7, nesterov=True) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_6 (Conv3D)           (None, 15, 50, 50, 8)     656
#
#  batch_normalization_6 (Batc  (None, 15, 50, 50, 8)    32
#  hNormalization)
#
#  activation_6 (Activation)   (None, 15, 50, 50, 8)     0
#
#  max_pooling3d_6 (MaxPooling  (None, 7, 25, 25, 8)     0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 7, 25, 25, 16)     3472
#
#  batch_normalization_7 (Batc  (None, 7, 25, 25, 16)    64
#  hNormalization)
#
#  activation_7 (Activation)   (None, 7, 25, 25, 16)     0
#
#  max_pooling3d_7 (MaxPooling  (None, 3, 12, 12, 16)    0
#  3D)
#
#  conv3d_8 (Conv3D)           (None, 3, 12, 12, 32)     13856
#
#  batch_normalization_8 (Batc  (None, 3, 12, 12, 32)    128
#  hNormalization)
#
#  activation_8 (Activation)   (None, 3, 12, 12, 32)     0
#
#  max_pooling3d_8 (MaxPooling  (None, 1, 6, 6, 32)      0
#  3D)
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_6 (Dense)             (None, 64)                73792
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, 4)
val_generator = generator(val_path, val_doc, 4)

# %%
model_name = 'model_exp2_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/4)
else:
    steps_per_epoch = (num_train_sequences//4) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/4)
else:
    validation_steps = (num_val_sequences//4) + 1

# %% [markdown]
# MODEL FITTING

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=10, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 4
# Epoch 1/10
# 166/166 [==============================] - ETA: 0s - loss: 1.8211 - categorical_accuracy: 0.2006Source path =  /home/datasets/Project_data/val ; batch size = 4
#
# Epoch 00001: val_loss improved from inf to 1.55955, saving model to model_exp2_2023-02-1419_48_31.959529/model-00001-1.82113-0.20060-1.55955-0.28846.h5
# 166/166 [==============================] - 140s 842ms/step - loss: 1.8211 - categorical_accuracy: 0.2006 - val_loss: 1.5595 - val_categorical_accuracy: 0.2885 - lr: 0.0010
# Epoch 2/10
# 166/166 [==============================] - ETA: 0s - loss: 1.6107 - categorical_accuracy: 0.2289
# Epoch 00002: val_loss improved from 1.55955 to 1.54523, saving model to model_exp2_2023-02-1419_48_31.959529/model-00002-1.61069-0.22892-1.54523-0.31731.h5
# 166/166 [==============================] - 105s 635ms/step - loss: 1.6107 - categorical_accuracy: 0.2289 - val_loss: 1.5452 - val_categorical_accuracy: 0.3173 - lr: 0.0010
# Epoch 3/10
# 166/166 [==============================] - ETA: 0s - loss: 1.5653 - categorical_accuracy: 0.2631
# Epoch 00003: val_loss improved from 1.54523 to 1.52953, saving model to model_exp2_2023-02-1419_48_31.959529/model-00003-1.56528-0.26305-1.52953-0.22115.h5
# 166/166 [==============================] - 104s 627ms/step - loss: 1.5653 - categorical_accuracy: 0.2631 - val_loss: 1.5295 - val_categorical_accuracy: 0.2212 - lr: 0.0010
# Epoch 4/10
# 166/166 [==============================] - ETA: 0s - loss: 1.5344 - categorical_accuracy: 0.3052
# Epoch 00004: val_loss improved from 1.52953 to 1.38298, saving model to model_exp2_2023-02-1419_48_31.959529/model-00004-1.53445-0.30522-1.38298-0.43269.h5
# 166/166 [==============================] - 103s 622ms/step - loss: 1.5344 - categorical_accuracy: 0.3052 - val_loss: 1.3830 - val_categorical_accuracy: 0.4327 - lr: 0.0010
# Epoch 5/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4834 - categorical_accuracy: 0.3715
# Epoch 00005: val_loss did not improve from 1.38298
# 166/166 [==============================] - 102s 613ms/step - loss: 1.4834 - categorical_accuracy: 0.3715 - val_loss: 1.5037 - val_categorical_accuracy: 0.4231 - lr: 0.0010
# Epoch 6/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4980 - categorical_accuracy: 0.3233
# Epoch 00006: val_loss improved from 1.38298 to 1.34261, saving model to model_exp2_2023-02-1419_48_31.959529/model-00006-1.49802-0.32329-1.34261-0.47115.h5
# 166/166 [==============================] - 103s 624ms/step - loss: 1.4980 - categorical_accuracy: 0.3233 - val_loss: 1.3426 - val_categorical_accuracy: 0.4712 - lr: 0.0010
# Epoch 7/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4746 - categorical_accuracy: 0.2992
# Epoch 00007: val_loss improved from 1.34261 to 1.21112, saving model to model_exp2_2023-02-1419_48_31.959529/model-00007-1.47463-0.29920-1.21112-0.55769.h5
# 166/166 [==============================] - 102s 612ms/step - loss: 1.4746 - categorical_accuracy: 0.2992 - val_loss: 1.2111 - val_categorical_accuracy: 0.5577 - lr: 0.0010
# Epoch 8/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4294 - categorical_accuracy: 0.3775
# Epoch 00008: val_loss did not improve from 1.21112
# 166/166 [==============================] - 107s 644ms/step - loss: 1.4294 - categorical_accuracy: 0.3775 - val_loss: 1.3632 - val_categorical_accuracy: 0.3173 - lr: 0.0010
# Epoch 9/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3812 - categorical_accuracy: 0.3936
# Epoch 00009: val_loss did not improve from 1.21112
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 166/166 [==============================] - 101s 610ms/step - loss: 1.3812 - categorical_accuracy: 0.3936 - val_loss: 1.2391 - val_categorical_accuracy: 0.5385 - lr: 0.0010
# Epoch 10/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3338 - categorical_accuracy: 0.4036
# Epoch 00010: val_loss improved from 1.21112 to 1.20581, saving model to model_exp2_2023-02-1419_48_31.959529/model-00010-1.33377-0.40361-1.20581-0.54808.h5
# 166/166 [==============================] - 108s 651ms/step - loss: 1.3338 - categorical_accuracy: 0.4036 - val_loss: 1.2058 - val_categorical_accuracy: 0.5481 - lr: 5.0000e-04

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][10-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][10-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])

    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(10)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

plot_history(history)
# Out:
# **Training Accuracy:** 0.4%
# **Validation Accuracy:** 0.55%

# %% [markdown]
# MODEL WITH CONV3D EXPERIMENT-3

# %% [markdown]
# Changing the optmizer from SGD to Adam

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4
num_epochs=25

img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

optimiser = optimizers.Adam(lr=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_18 (Conv3D)          (None, 15, 50, 50, 8)     656
#
#  batch_normalization_18 (Bat  (None, 15, 50, 50, 8)    32
#  chNormalization)
#
#  activation_18 (Activation)  (None, 15, 50, 50, 8)     0
#
#  max_pooling3d_18 (MaxPoolin  (None, 7, 25, 25, 8)     0
#  g3D)
#
#  conv3d_19 (Conv3D)          (None, 7, 25, 25, 16)     3472
#
#  batch_normalization_19 (Bat  (None, 7, 25, 25, 16)    64
#  chNormalization)
#
#  activation_19 (Activation)  (None, 7, 25, 25, 16)     0
#
#  max_pooling3d_19 (MaxPoolin  (None, 3, 12, 12, 16)    0
#  g3D)
#
#  conv3d_20 (Conv3D)          (None, 3, 12, 12, 32)     13856
#
#  batch_normalization_20 (Bat  (None, 3, 12, 12, 32)    128
#  chNormalization)
#
#  activation_20 (Activation)  (None, 3, 12, 12, 32)     0
#
#  max_pooling3d_20 (MaxPoolin  (None, 1, 6, 6, 32)      0
#  g3D)
#
#  flatten_6 (Flatten)         (None, 1152)              0
#
#  dense_18 (Dense)            (None, 64)                73792
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 64)                4160
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_20 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, 4)
val_generator = generator(val_path, val_doc, 4)

# %%
model_name = 'model_exp5_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/4)
else:
    steps_per_epoch = (num_train_sequences//4) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/4)
else:
    validation_steps = (num_val_sequences//4) + 1

# %% [markdown]
# MODEL FITTING

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=10, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4293 - categorical_accuracy: 0.3353
# Epoch 00001: val_loss did not improve from 1.23205
# 166/166 [==============================] - 103s 622ms/step - loss: 1.4293 - categorical_accuracy: 0.3353 - val_loss: 1.3305 - val_categorical_accuracy: 0.4300 - lr: 1.0000e-04
# Epoch 2/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4202 - categorical_accuracy: 0.3655
# Epoch 00002: val_loss did not improve from 1.23205
# 166/166 [==============================] - 100s 603ms/step - loss: 1.4202 - categorical_accuracy: 0.3655 - val_loss: 1.2696 - val_categorical_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 3/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3762 - categorical_accuracy: 0.4116
# Epoch 00003: val_loss did not improve from 1.23205
# 166/166 [==============================] - 102s 613ms/step - loss: 1.3762 - categorical_accuracy: 0.4116 - val_loss: 1.2646 - val_categorical_accuracy: 0.5900 - lr: 1.0000e-04
# Epoch 4/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3573 - categorical_accuracy: 0.3795
# Epoch 00004: val_loss improved from 1.23205 to 1.18271, saving model to model_exp5_2023-02-1419_48_31.959529/model-00004-1.35729-0.37952-1.18271-0.57000.h5
# 166/166 [==============================] - 101s 608ms/step - loss: 1.3573 - categorical_accuracy: 0.3795 - val_loss: 1.1827 - val_categorical_accuracy: 0.5700 - lr: 1.0000e-04
# Epoch 5/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3376 - categorical_accuracy: 0.4157
# Epoch 00005: val_loss did not improve from 1.18271
# 166/166 [==============================] - 102s 616ms/step - loss: 1.3376 - categorical_accuracy: 0.4157 - val_loss: 1.2177 - val_categorical_accuracy: 0.4100 - lr: 1.0000e-04
# Epoch 6/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3272 - categorical_accuracy: 0.4398
# Epoch 00006: val_loss improved from 1.18271 to 1.18171, saving model to model_exp5_2023-02-1419_48_31.959529/model-00006-1.32717-0.43976-1.18171-0.55000.h5
# 166/166 [==============================] - 100s 602ms/step - loss: 1.3272 - categorical_accuracy: 0.4398 - val_loss: 1.1817 - val_categorical_accuracy: 0.5500 - lr: 1.0000e-04
# Epoch 7/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3019 - categorical_accuracy: 0.4016
# Epoch 00007: val_loss improved from 1.18171 to 1.18004, saving model to model_exp5_2023-02-1419_48_31.959529/model-00007-1.30188-0.40161-1.18004-0.46000.h5
# 166/166 [==============================] - 100s 605ms/step - loss: 1.3019 - categorical_accuracy: 0.4016 - val_loss: 1.1800 - val_categorical_accuracy: 0.4600 - lr: 1.0000e-04
# Epoch 8/10
# 166/166 [==============================] - ETA: 0s - loss: 1.2678 - categorical_accuracy: 0.4337
# Epoch 00008: val_loss improved from 1.18004 to 1.17557, saving model to model_exp5_2023-02-1419_48_31.959529/model-00008-1.26779-0.43373-1.17557-0.46000.h5
# 166/166 [==============================] - 101s 608ms/step - loss: 1.2678 - categorical_accuracy: 0.4337 - val_loss: 1.1756 - val_categorical_accuracy: 0.4600 - lr: 1.0000e-04
# Epoch 9/10
# 166/166 [==============================] - ETA: 0s - loss: 1.2905 - categorical_accuracy: 0.4458
# Epoch 00009: val_loss improved from 1.17557 to 1.09394, saving model to model_exp5_2023-02-1419_48_31.959529/model-00009-1.29049-0.44578-1.09394-0.50000.h5
# 166/166 [==============================] - 102s 612ms/step - loss: 1.2905 - categorical_accuracy: 0.4458 - val_loss: 1.0939 - val_categorical_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 10/10
# 166/166 [==============================] - ETA: 0s - loss: 1.2200 - categorical_accuracy: 0.4799
# Epoch 00010: val_loss did not improve from 1.09394
# 166/166 [==============================] - 100s 601ms/step - loss: 1.2200 - categorical_accuracy: 0.4799 - val_loss: 1.1145 - val_categorical_accuracy: 0.5100 - lr: 1.0000e-04

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][10-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][10-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])

    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(10)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

plot_history(history)
# Out:
# **Training Accuracy:** 0.48%
# **Validation Accuracy:** 0.51%

# %% [markdown]
# MODEL WITH CONV3D EXPERIMENT-4

# %% [markdown]
# Reducing the number of frames from 15 to 10

# %%
total_frames = 30
num_frames = 10
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4
num_epochs=25

img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

optimiser = optimizers.Adam(learning_rate=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 10, 50, 50, 8)     656
#
#  batch_normalization_12 (Bat  (None, 10, 50, 50, 8)    32
#  chNormalization)
#
#  activation_12 (Activation)  (None, 10, 50, 50, 8)     0
#
#  max_pooling3d_12 (MaxPoolin  (None, 5, 25, 25, 8)     0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 5, 25, 25, 16)     3472
#
#  batch_normalization_13 (Bat  (None, 5, 25, 25, 16)    64
#  chNormalization)
#
#  activation_13 (Activation)  (None, 5, 25, 25, 16)     0
#
#  max_pooling3d_13 (MaxPoolin  (None, 2, 12, 12, 16)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 2, 12, 12, 32)     13856
#
#  batch_normalization_14 (Bat  (None, 2, 12, 12, 32)    128
#  chNormalization)
#
#  activation_14 (Activation)  (None, 2, 12, 12, 32)     0
#
#  max_pooling3d_14 (MaxPoolin  (None, 1, 6, 6, 32)      0
#  g3D)
#
#  flatten_4 (Flatten)         (None, 1152)              0
#
#  dense_12 (Dense)            (None, 64)                73792
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, 4)
val_generator = generator(val_path, val_doc,4)

# %%
model_name = 'model_exp6_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/4)
else:
    steps_per_epoch = (num_train_sequences//4) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/4)
else:
    validation_steps = (num_val_sequences//4) + 1

# %% [markdown]
# MODEL FITTING

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=10, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 4
# Epoch 1/10
# 166/166 [==============================] - ETA: 0s - loss: 1.8449 - categorical_accuracy: 0.2474Source path =  /home/datasets/Project_data/val ; batch size = 4
#
# Epoch 00001: val_loss improved from inf to 1.55205, saving model to model_exp6_2023-02-1419_48_31.959529/model-00001-1.84495-0.24736-1.55205-0.35000.h5
# 166/166 [==============================] - 88s 528ms/step - loss: 1.8449 - categorical_accuracy: 0.2474 - val_loss: 1.5520 - val_categorical_accuracy: 0.3500 - lr: 2.0000e-04
# Epoch 2/10
# 166/166 [==============================] - ETA: 0s - loss: 1.5982 - categorical_accuracy: 0.2068
# Epoch 00002: val_loss improved from 1.55205 to 1.53931, saving model to model_exp6_2023-02-1419_48_31.959529/model-00002-1.59820-0.20683-1.53931-0.34000.h5
# 166/166 [==============================] - 69s 414ms/step - loss: 1.5982 - categorical_accuracy: 0.2068 - val_loss: 1.5393 - val_categorical_accuracy: 0.3400 - lr: 2.0000e-04
# Epoch 3/10
# 166/166 [==============================] - ETA: 0s - loss: 1.6109 - categorical_accuracy: 0.1948
# Epoch 00003: val_loss did not improve from 1.53931
# 166/166 [==============================] - 68s 409ms/step - loss: 1.6109 - categorical_accuracy: 0.1948 - val_loss: 1.5600 - val_categorical_accuracy: 0.2900 - lr: 2.0000e-04
# Epoch 4/10
# 166/166 [==============================] - ETA: 0s - loss: 1.5770 - categorical_accuracy: 0.2510
# Epoch 00004: val_loss improved from 1.53931 to 1.47797, saving model to model_exp6_2023-02-1419_48_31.959529/model-00004-1.57701-0.25100-1.47797-0.31000.h5
# 166/166 [==============================] - 69s 413ms/step - loss: 1.5770 - categorical_accuracy: 0.2510 - val_loss: 1.4780 - val_categorical_accuracy: 0.3100 - lr: 2.0000e-04
# Epoch 5/10
# 166/166 [==============================] - ETA: 0s - loss: 1.5783 - categorical_accuracy: 0.2430
# Epoch 00005: val_loss improved from 1.47797 to 1.46694, saving model to model_exp6_2023-02-1419_48_31.959529/model-00005-1.57831-0.24297-1.46694-0.50000.h5
# 166/166 [==============================] - 69s 415ms/step - loss: 1.5783 - categorical_accuracy: 0.2430 - val_loss: 1.4669 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 6/10
# 166/166 [==============================] - ETA: 0s - loss: 1.5082 - categorical_accuracy: 0.3112
# Epoch 00006: val_loss improved from 1.46694 to 1.40040, saving model to model_exp6_2023-02-1419_48_31.959529/model-00006-1.50818-0.31124-1.40040-0.33000.h5
# 166/166 [==============================] - 69s 418ms/step - loss: 1.5082 - categorical_accuracy: 0.3112 - val_loss: 1.4004 - val_categorical_accuracy: 0.3300 - lr: 2.0000e-04
# Epoch 7/10
# 166/166 [==============================] - ETA: 0s - loss: 1.5139 - categorical_accuracy: 0.3173
# Epoch 00007: val_loss improved from 1.40040 to 1.36457, saving model to model_exp6_2023-02-1419_48_31.959529/model-00007-1.51395-0.31727-1.36457-0.42000.h5
# 166/166 [==============================] - 69s 415ms/step - loss: 1.5139 - categorical_accuracy: 0.3173 - val_loss: 1.3646 - val_categorical_accuracy: 0.4200 - lr: 2.0000e-04
# Epoch 8/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4802 - categorical_accuracy: 0.2932
# Epoch 00008: val_loss improved from 1.36457 to 1.36294, saving model to model_exp6_2023-02-1419_48_31.959529/model-00008-1.48018-0.29317-1.36294-0.35000.h5
# 166/166 [==============================] - 68s 413ms/step - loss: 1.4802 - categorical_accuracy: 0.2932 - val_loss: 1.3629 - val_categorical_accuracy: 0.3500 - lr: 2.0000e-04
# Epoch 9/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4860 - categorical_accuracy: 0.3133
# Epoch 00009: val_loss improved from 1.36294 to 1.33760, saving model to model_exp6_2023-02-1419_48_31.959529/model-00009-1.48604-0.31325-1.33760-0.59000.h5
# 166/166 [==============================] - 69s 418ms/step - loss: 1.4860 - categorical_accuracy: 0.3133 - val_loss: 1.3376 - val_categorical_accuracy: 0.5900 - lr: 2.0000e-04
# Epoch 10/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4267 - categorical_accuracy: 0.3514
# Epoch 00010: val_loss improved from 1.33760 to 1.26433, saving model to model_exp6_2023-02-1419_48_31.959529/model-00010-1.42667-0.35141-1.26433-0.44000.h5
# 166/166 [==============================] - 69s 418ms/step - loss: 1.4267 - categorical_accuracy: 0.3514 - val_loss: 1.2643 - val_categorical_accuracy: 0.4400 - lr: 2.0000e-04

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][10-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][10-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])

    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(10)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

plot_history(history)
# Out:
# **Training Accuracy:** 0.35%
# **Validation Accuracy:** 0.44%

# %% [markdown]
# MODEL WITH CONV3D EXPERIMENT-5

# %% [markdown]
# Reducing the dropout rate from 0.5 to 0.25

# %%
total_frames = 30
num_frames = 10
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4

num_epochs=25

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

optimiser = optimizers.Adam(lr=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_15 (Conv3D)          (None, 10, 50, 50, 8)     656
#
#  batch_normalization_15 (Bat  (None, 10, 50, 50, 8)    32
#  chNormalization)
#
#  activation_15 (Activation)  (None, 10, 50, 50, 8)     0
#
#  max_pooling3d_15 (MaxPoolin  (None, 5, 25, 25, 8)     0
#  g3D)
#
#  conv3d_16 (Conv3D)          (None, 5, 25, 25, 16)     3472
#
#  batch_normalization_16 (Bat  (None, 5, 25, 25, 16)    64
#  chNormalization)
#
#  activation_16 (Activation)  (None, 5, 25, 25, 16)     0
#
#  max_pooling3d_16 (MaxPoolin  (None, 2, 12, 12, 16)    0
#  g3D)
#
#  conv3d_17 (Conv3D)          (None, 2, 12, 12, 32)     13856
#
#  batch_normalization_17 (Bat  (None, 2, 12, 12, 32)    128
#  chNormalization)
#
#  activation_17 (Activation)  (None, 2, 12, 12, 32)     0
#
#  max_pooling3d_17 (MaxPoolin  (None, 1, 6, 6, 32)      0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 1152)              0
#
#  dense_15 (Dense)            (None, 64)                73792
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, 4)
val_generator = generator(val_path, val_doc,4)

# %%
model_name = 'model_exp7_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/4)
else:
    steps_per_epoch = (num_train_sequences//4) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/4)
else:
    validation_steps = (num_val_sequences//4) + 1

# %% [markdown]
# MODEL FITTING

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=10, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 4
# Epoch 1/10
# 166/166 [==============================] - ETA: 0s - loss: 1.7049 - categorical_accuracy: 0.2745Source path =  /home/datasets/Project_data/val ; batch size = 4
#
# Epoch 00001: val_loss improved from inf to 1.58369, saving model to model_exp7_2023-02-1419_48_31.959529/model-00001-1.70492-0.27451-1.58369-0.25000.h5
# 166/166 [==============================] - 89s 534ms/step - loss: 1.7049 - categorical_accuracy: 0.2745 - val_loss: 1.5837 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 2/10
# 166/166 [==============================] - ETA: 0s - loss: 1.4701 - categorical_accuracy: 0.3454
# Epoch 00002: val_loss improved from 1.58369 to 1.30098, saving model to model_exp7_2023-02-1419_48_31.959529/model-00002-1.47009-0.34538-1.30098-0.39000.h5
# 166/166 [==============================] - 68s 408ms/step - loss: 1.4701 - categorical_accuracy: 0.3454 - val_loss: 1.3010 - val_categorical_accuracy: 0.3900 - lr: 2.0000e-04
# Epoch 3/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3738 - categorical_accuracy: 0.4458
# Epoch 00003: val_loss improved from 1.30098 to 1.17178, saving model to model_exp7_2023-02-1419_48_31.959529/model-00003-1.37377-0.44578-1.17178-0.51000.h5
# 166/166 [==============================] - 70s 420ms/step - loss: 1.3738 - categorical_accuracy: 0.4458 - val_loss: 1.1718 - val_categorical_accuracy: 0.5100 - lr: 2.0000e-04
# Epoch 4/10
# 166/166 [==============================] - ETA: 0s - loss: 1.3022 - categorical_accuracy: 0.4398
# Epoch 00004: val_loss improved from 1.17178 to 1.08440, saving model to model_exp7_2023-02-1419_48_31.959529/model-00004-1.30217-0.43976-1.08440-0.60000.h5
# 166/166 [==============================] - 69s 416ms/step - loss: 1.3022 - categorical_accuracy: 0.4398 - val_loss: 1.0844 - val_categorical_accuracy: 0.6000 - lr: 2.0000e-04
# Epoch 5/10
# 166/166 [==============================] - ETA: 0s - loss: 1.1622 - categorical_accuracy: 0.4900
# Epoch 00005: val_loss did not improve from 1.08440
# 166/166 [==============================] - 69s 418ms/step - loss: 1.1622 - categorical_accuracy: 0.4900 - val_loss: 1.2626 - val_categorical_accuracy: 0.5100 - lr: 2.0000e-04
# Epoch 6/10
# 166/166 [==============================] - ETA: 0s - loss: 1.1030 - categorical_accuracy: 0.5301
# Epoch 00006: val_loss improved from 1.08440 to 0.89090, saving model to model_exp7_2023-02-1419_48_31.959529/model-00006-1.10301-0.53012-0.89090-0.64000.h5
# 166/166 [==============================] - 68s 411ms/step - loss: 1.1030 - categorical_accuracy: 0.5301 - val_loss: 0.8909 - val_categorical_accuracy: 0.6400 - lr: 2.0000e-04
# Epoch 7/10
# 166/166 [==============================] - ETA: 0s - loss: 0.9927 - categorical_accuracy: 0.6145
# Epoch 00007: val_loss did not improve from 0.89090
# 166/166 [==============================] - 69s 414ms/step - loss: 0.9927 - categorical_accuracy: 0.6145 - val_loss: 1.1469 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 8/10
# 166/166 [==============================] - ETA: 0s - loss: 0.9819 - categorical_accuracy: 0.6165
# Epoch 00008: val_loss improved from 0.89090 to 0.85489, saving model to model_exp7_2023-02-1419_48_31.959529/model-00008-0.98190-0.61647-0.85489-0.68000.h5
# 166/166 [==============================] - 69s 414ms/step - loss: 0.9819 - categorical_accuracy: 0.6165 - val_loss: 0.8549 - val_categorical_accuracy: 0.6800 - lr: 2.0000e-04
# Epoch 9/10
# 166/166 [==============================] - ETA: 0s - loss: 0.8556 - categorical_accuracy: 0.6566
# Epoch 00009: val_loss improved from 0.85489 to 0.80625, saving model to model_exp7_2023-02-1419_48_31.959529/model-00009-0.85564-0.65663-0.80625-0.75000.h5
# 166/166 [==============================] - 69s 418ms/step - loss: 0.8556 - categorical_accuracy: 0.6566 - val_loss: 0.8063 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 10/10
# 166/166 [==============================] - ETA: 0s - loss: 0.7798 - categorical_accuracy: 0.6928
# Epoch 00010: val_loss improved from 0.80625 to 0.72067, saving model to model_exp7_2023-02-1419_48_31.959529/model-00010-0.77975-0.69277-0.72067-0.78000.h5
# 166/166 [==============================] - 69s 418ms/step - loss: 0.7798 - categorical_accuracy: 0.6928 - val_loss: 0.7207 - val_categorical_accuracy: 0.7800 - lr: 2.0000e-04

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][10-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][10-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])

    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(10)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

plot_history(history)
# Out:
# **Training Accuracy:** 0.69%
# **Validation Accuracy:** 0.78%

# %% [markdown]
# MODEL WITH CONV3D EXPERIMENT-6

# %% [markdown]
# Increasing the number of epochs from 25 to 35

# %%
#Using image_height as 50 , image_width as 50 ,gestures As 5,total_frames As 30,num_frames As 10
num_frames = 10
total_frames = 30
num_frames = 10
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4

num_epochs=35

# %% [markdown]
# MODEL BUILDING

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation, Conv3D, MaxPooling3D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import optimizers
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

optimiser = optimizers.Adam(learning_rate=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_9 (Conv3D)           (None, 10, 50, 50, 8)     656
#
#  batch_normalization_9 (Batc  (None, 10, 50, 50, 8)    32
#  hNormalization)
#
#  activation_9 (Activation)   (None, 10, 50, 50, 8)     0
#
#  max_pooling3d_9 (MaxPooling  (None, 5, 25, 25, 8)     0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 5, 25, 25, 16)     3472
#
#  batch_normalization_10 (Bat  (None, 5, 25, 25, 16)    64
#  chNormalization)
#
#  activation_10 (Activation)  (None, 5, 25, 25, 16)     0
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 12, 12, 16)    0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 12, 12, 32)     13856
#
#  batch_normalization_11 (Bat  (None, 2, 12, 12, 32)    128
#  chNormalization)
#
#  activation_11 (Activation)  (None, 2, 12, 12, 32)     0
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 6, 6, 32)      0
#  g3D)
#
#  flatten_3 (Flatten)         (None, 1152)              0
#
#  dense_9 (Dense)             (None, 64)                73792
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_exp8_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# FITTING MODEL

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 4
# Epoch 1/35
# 166/166 [==============================] - ETA: 0s - loss: 1.8199 - categorical_accuracy: 0.2685Source path =  /home/datasets/Project_data/val ; batch size = 4
#
# Epoch 00001: val_loss improved from inf to 1.44814, saving model to model_exp8_2023-02-1415_16_12.243256/model-00001-1.81991-0.26848-1.44814-0.34000.h5
# 166/166 [==============================] - 92s 553ms/step - loss: 1.8199 - categorical_accuracy: 0.2685 - val_loss: 1.4481 - val_categorical_accuracy: 0.3400 - lr: 2.0000e-04
# Epoch 2/35
# 166/166 [==============================] - ETA: 0s - loss: 1.5140 - categorical_accuracy: 0.3353
# Epoch 00002: val_loss improved from 1.44814 to 1.23788, saving model to model_exp8_2023-02-1415_16_12.243256/model-00002-1.51395-0.33534-1.23788-0.47000.h5
# 166/166 [==============================] - 72s 432ms/step - loss: 1.5140 - categorical_accuracy: 0.3353 - val_loss: 1.2379 - val_categorical_accuracy: 0.4700 - lr: 2.0000e-04
# Epoch 3/35
# 166/166 [==============================] - ETA: 0s - loss: 1.3914 - categorical_accuracy: 0.3815
# Epoch 00003: val_loss improved from 1.23788 to 1.19067, saving model to model_exp8_2023-02-1415_16_12.243256/model-00003-1.39145-0.38153-1.19067-0.53000.h5
# 166/166 [==============================] - 70s 420ms/step - loss: 1.3914 - categorical_accuracy: 0.3815 - val_loss: 1.1907 - val_categorical_accuracy: 0.5300 - lr: 2.0000e-04
# Epoch 4/35
# 166/166 [==============================] - ETA: 0s - loss: 1.2673 - categorical_accuracy: 0.4558
# Epoch 00004: val_loss improved from 1.19067 to 1.07458, saving model to model_exp8_2023-02-1415_16_12.243256/model-00004-1.26732-0.45582-1.07458-0.57000.h5
# 166/166 [==============================] - 70s 423ms/step - loss: 1.2673 - categorical_accuracy: 0.4558 - val_loss: 1.0746 - val_categorical_accuracy: 0.5700 - lr: 2.0000e-04
# Epoch 5/35
# 166/166 [==============================] - ETA: 0s - loss: 1.2064 - categorical_accuracy: 0.5120
# Epoch 00005: val_loss did not improve from 1.07458
# 166/166 [==============================] - 69s 414ms/step - loss: 1.2064 - categorical_accuracy: 0.5120 - val_loss: 1.4565 - val_categorical_accuracy: 0.3500 - lr: 2.0000e-04
# Epoch 6/35
# 166/166 [==============================] - ETA: 0s - loss: 1.1418 - categorical_accuracy: 0.5060
# Epoch 00006: val_loss improved from 1.07458 to 0.95227, saving model to model_exp8_2023-02-1415_16_12.243256/model-00006-1.14182-0.50602-0.95227-0.69000.h5
# 166/166 [==============================] - 69s 417ms/step - loss: 1.1418 - categorical_accuracy: 0.5060 - val_loss: 0.9523 - val_categorical_accuracy: 0.6900 - lr: 2.0000e-04
# Epoch 7/35
# 166/166 [==============================] - ETA: 0s - loss: 1.0576 - categorical_accuracy: 0.5683
# Epoch 00007: val_loss improved from 0.95227 to 0.87458, saving model to model_exp8_2023-02-1415_16_12.243256/model-00007-1.05760-0.56827-0.87458-0.67000.h5
# 166/166 [==============================] - 68s 410ms/step - loss: 1.0576 - categorical_accuracy: 0.5683 - val_loss: 0.8746 - val_categorical_accuracy: 0.6700 - lr: 2.0000e-04
# Epoch 8/35
# 166/166 [==============================] - ETA: 0s - loss: 0.9755 - categorical_accuracy: 0.6104
# Epoch 00008: val_loss did not improve from 0.87458
# 166/166 [==============================] - 71s 429ms/step - loss: 0.9755 - categorical_accuracy: 0.6104 - val_loss: 0.9994 - val_categorical_accuracy: 0.5600 - lr: 2.0000e-04
# Epoch 9/35
# 166/166 [==============================] - ETA: 0s - loss: 0.9012 - categorical_accuracy: 0.6466
# Epoch 00009: val_loss improved from 0.87458 to 0.84539, saving model to model_exp8_2023-02-1415_16_12.243256/model-00009-0.90120-0.64659-0.84539-0.67000.h5
# 166/166 [==============================] - 68s 412ms/step - loss: 0.9012 - categorical_accuracy: 0.6466 - val_loss: 0.8454 - val_categorical_accuracy: 0.6700 - lr: 2.0000e-04
# Epoch 10/35
# 166/166 [==============================] - ETA: 0s - loss: 0.8835 - categorical_accuracy: 0.6727
# Epoch 00010: val_loss improved from 0.84539 to 0.77880, saving model to model_exp8_2023-02-1415_16_12.243256/model-00010-0.88348-0.67269-0.77880-0.71000.h5
# 166/166 [==============================] - 70s 424ms/step - loss: 0.8835 - categorical_accuracy: 0.6727 - val_loss: 0.7788 - val_categorical_accuracy: 0.7100 - lr: 2.0000e-04
# Epoch 11/35
# 166/166 [==============================] - ETA: 0s - loss: 0.6848 - categorical_accuracy: 0.7510
# Epoch 00011: val_loss improved from 0.77880 to 0.60779, saving model to model_exp8_2023-02-1415_16_12.243256/model-00011-0.68484-0.75100-0.60779-0.77000.h5
# 166/166 [==============================] - 73s 439ms/step - loss: 0.6848 - categorical_accuracy: 0.7510 - val_loss: 0.6078 - val_categorical_accuracy: 0.7700 - lr: 2.0000e-04
# Epoch 12/35
# 166/166 [==============================] - ETA: 0s - loss: 0.7882 - categorical_accuracy: 0.6968
# Epoch 00012: val_loss did not improve from 0.60779
# 166/166 [==============================] - 73s 439ms/step - loss: 0.7882 - categorical_accuracy: 0.6968 - val_loss: 0.6858 - val_categorical_accuracy: 0.7300 - lr: 2.0000e-04
# Epoch 13/35
# 166/166 [==============================] - ETA: 0s - loss: 0.6151 - categorical_accuracy: 0.7912
# Epoch 00013: val_loss did not improve from 0.60779
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 166/166 [==============================] - 72s 434ms/step - loss: 0.6151 - categorical_accuracy: 0.7912 - val_loss: 0.6323 - val_categorical_accuracy: 0.7800 - lr: 2.0000e-04
# Epoch 14/35
# 166/166 [==============================] - ETA: 0s - loss: 0.5313 - categorical_accuracy: 0.8153
# Epoch 00014: val_loss improved from 0.60779 to 0.56049, saving model to model_exp8_2023-02-1415_16_12.243256/model-00014-0.53128-0.81526-0.56049-0.83000.h5
# 166/166 [==============================] - 70s 425ms/step - loss: 0.5313 - categorical_accuracy: 0.8153 - val_loss: 0.5605 - val_categorical_accuracy: 0.8300 - lr: 1.0000e-04
# Epoch 15/35
# 166/166 [==============================] - ETA: 0s - loss: 0.4785 - categorical_accuracy: 0.8494
# Epoch 00015: val_loss did not improve from 0.56049
# 166/166 [==============================] - 70s 422ms/step - loss: 0.4785 - categorical_accuracy: 0.8494 - val_loss: 0.7170 - val_categorical_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 16/35
# 166/166 [==============================] - ETA: 0s - loss: 0.4725 - categorical_accuracy: 0.8293
# Epoch 00016: val_loss improved from 0.56049 to 0.49779, saving model to model_exp8_2023-02-1415_16_12.243256/model-00016-0.47252-0.82932-0.49779-0.85000.h5
# 166/166 [==============================] - 69s 419ms/step - loss: 0.4725 - categorical_accuracy: 0.8293 - val_loss: 0.4978 - val_categorical_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 17/35
# 166/166 [==============================] - ETA: 0s - loss: 0.4524 - categorical_accuracy: 0.8293
# Epoch 00017: val_loss did not improve from 0.49779
# 166/166 [==============================] - 71s 425ms/step - loss: 0.4524 - categorical_accuracy: 0.8293 - val_loss: 0.6268 - val_categorical_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 18/35
# 166/166 [==============================] - ETA: 0s - loss: 0.4588 - categorical_accuracy: 0.8273
# Epoch 00018: val_loss did not improve from 0.49779
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 166/166 [==============================] - 68s 411ms/step - loss: 0.4588 - categorical_accuracy: 0.8273 - val_loss: 0.5462 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 19/35
# 166/166 [==============================] - ETA: 0s - loss: 0.4226 - categorical_accuracy: 0.8574
# Epoch 00019: val_loss improved from 0.49779 to 0.45596, saving model to model_exp8_2023-02-1415_16_12.243256/model-00019-0.42263-0.85743-0.45596-0.84000.h5
# 166/166 [==============================] - 69s 417ms/step - loss: 0.4226 - categorical_accuracy: 0.8574 - val_loss: 0.4560 - val_categorical_accuracy: 0.8400 - lr: 5.0000e-05
# Epoch 20/35
# 166/166 [==============================] - ETA: 0s - loss: 0.3623 - categorical_accuracy: 0.8574
# Epoch 00020: val_loss did not improve from 0.45596
# 166/166 [==============================] - 69s 415ms/step - loss: 0.3623 - categorical_accuracy: 0.8574 - val_loss: 0.6195 - val_categorical_accuracy: 0.7600 - lr: 5.0000e-05
# Epoch 21/35
# 166/166 [==============================] - ETA: 0s - loss: 0.3486 - categorical_accuracy: 0.8795
# Epoch 00021: val_loss did not improve from 0.45596
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 166/166 [==============================] - 68s 411ms/step - loss: 0.3486 - categorical_accuracy: 0.8795 - val_loss: 0.4964 - val_categorical_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 22/35
# 166/166 [==============================] - ETA: 0s - loss: 0.3426 - categorical_accuracy: 0.8835
# Epoch 00022: val_loss did not improve from 0.45596
# 166/166 [==============================] - 71s 426ms/step - loss: 0.3426 - categorical_accuracy: 0.8835 - val_loss: 0.5199 - val_categorical_accuracy: 0.7900 - lr: 2.5000e-05
# Epoch 23/35
# 166/166 [==============================] - ETA: 0s - loss: 0.3558 - categorical_accuracy: 0.8855
# Epoch 00023: val_loss did not improve from 0.45596
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 166/166 [==============================] - 70s 423ms/step - loss: 0.3558 - categorical_accuracy: 0.8855 - val_loss: 0.5046 - val_categorical_accuracy: 0.7700 - lr: 2.5000e-05
# Epoch 24/35
# 166/166 [==============================] - ETA: 0s - loss: 0.2955 - categorical_accuracy: 0.9096
# Epoch 00024: val_loss did not improve from 0.45596
# 166/166 [==============================] - 69s 417ms/step - loss: 0.2955 - categorical_accuracy: 0.9096 - val_loss: 0.4701 - val_categorical_accuracy: 0.8200 - lr: 1.2500e-05
# Epoch 25/35
# 166/166 [==============================] - ETA: 0s - loss: 0.2882 - categorical_accuracy: 0.9116
# Epoch 00025: val_loss did not improve from 0.45596
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 166/166 [==============================] - 68s 413ms/step - loss: 0.2882 - categorical_accuracy: 0.9116 - val_loss: 0.4891 - val_categorical_accuracy: 0.8100 - lr: 1.2500e-05
# Epoch 26/35
# 166/166 [==============================] - ETA: 0s - loss: 0.2887 - categorical_accuracy: 0.9016
# Epoch 00026: val_loss did not improve from 0.45596
# 166/166 [==============================] - 69s 418ms/step - loss: 0.2887 - categorical_accuracy: 0.9016 - val_loss: 0.4837 - val_categorical_accuracy: 0.8100 - lr: 6.2500e-06
# Epoch 27/35
# 166/166 [==============================] - ETA: 0s - loss: 0.2904 - categorical_accuracy: 0.9076
# Epoch 00027: val_loss did not improve from 0.45596
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 166/166 [==============================] - 69s 419ms/step - loss: 0.2904 - categorical_accuracy: 0.9076 - val_loss: 0.4798 - val_categorical_accuracy: 0.8300 - lr: 6.2500e-06
# Epoch 28/35
# 166/166 [==============================] - ETA: 0s - loss: 0.2863 - categorical_accuracy: 0.9036
# Epoch 00028: val_loss did not improve from 0.45596
# 166/166 [==============================] - 71s 428ms/step - loss: 0.2863 - categorical_accuracy: 0.9036 - val_loss: 0.4722 - val_categorical_accuracy: 0.8000 - lr: 3.1250e-06
# Epoch 29/35
# 166/166 [==============================] - ETA: 0s - loss: 0.3186 - categorical_accuracy: 0.8976
# Epoch 00029: val_loss did not improve from 0.45596
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 166/166 [==============================] - 70s 420ms/step - loss: 0.3186 - categorical_accuracy: 0.8976 - val_loss: 0.5024 - val_categorical_accuracy: 0.8100 - lr: 3.1250e-06
# Epoch 30/35
# 166/166 [==============================] - ETA: 0s - loss: 0.3194 - categorical_accuracy: 0.8896
# Epoch 00030: val_loss improved from 0.45596 to 0.43245, saving model to model_exp8_2023-02-1415_16_12.243256/model-00030-0.31940-0.88956-0.43245-0.83000.h5
# 166/166 [==============================] - 71s 428ms/step - loss: 0.3194 - categorical_accuracy: 0.8896 - val_loss: 0.4325 - val_categorical_accuracy: 0.8300 - lr: 1.5625e-06
# Epoch 31/35
# 166/166 [==============================] - ETA: 0s - loss: 0.3019 - categorical_accuracy: 0.9116
# Epoch 00031: val_loss did not improve from 0.43245
# 166/166 [==============================] - 71s 427ms/step - loss: 0.3019 - categorical_accuracy: 0.9116 - val_loss: 0.4787 - val_categorical_accuracy: 0.8400 - lr: 1.5625e-06
# Epoch 32/35
# 166/166 [==============================] - ETA: 0s - loss: 0.2642 - categorical_accuracy: 0.9237
# Epoch 00032: val_loss did not improve from 0.43245
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 166/166 [==============================] - 70s 420ms/step - loss: 0.2642 - categorical_accuracy: 0.9237 - val_loss: 0.6160 - val_categorical_accuracy: 0.7400 - lr: 1.5625e-06
# Epoch 33/35
# 166/166 [==============================] - ETA: 0s - loss: 0.2844 - categorical_accuracy: 0.9076
# Epoch 00033: val_loss did not improve from 0.43245
# 166/166 [==============================] - 70s 423ms/step - loss: 0.2844 - categorical_accuracy: 0.9076 - val_loss: 0.4514 - val_categorical_accuracy: 0.8300 - lr: 7.8125e-07
# Epoch 34/35
# 166/166 [==============================] - ETA: 0s - loss: 0.3108 - categorical_accuracy: 0.8916
# Epoch 00034: val_loss did not improve from 0.43245
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 166/166 [==============================] - 76s 460ms/step - loss: 0.3108 - categorical_accuracy: 0.8916 - val_loss: 0.4735 - val_categorical_accuracy: 0.7900 - lr: 7.8125e-07
# Epoch 35/35
# 166/166 [==============================] - ETA: 0s - loss: 0.2813 - categorical_accuracy: 0.9016
# Epoch 00035: val_loss did not improve from 0.43245
# 166/166 [==============================] - 70s 420ms/step - loss: 0.2813 - categorical_accuracy: 0.9016 - val_loss: 0.4797 - val_categorical_accuracy: 0.8000 - lr: 3.9062e-07

# %% [markdown]
# PLOTTING THE MODEL OF COV3D

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][num_epochs-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][num_epochs-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])

    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(num_epochs)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

plot_history(history)
# Out:
# **Training Accuracy:** 0.9%
# **Validation Accuracy:** 0.8%

# %% [markdown]
# ACCURACY OF COV3D IS 0.9 % FOR TRAINING AND 0.8% VALIDATION ACCURACY
# ->After Trail and error finally after using epoch size of 35 , batch size as 4 ,img_width as 50 and img_height as 50 got validation accuracy as 80% and training accuracy 90%

# %% [markdown]
# MODEL WITH TIMEDISTRIBUTED AND CONV2D

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout,LSTM,Conv3D,Conv2D, MaxPooling3D,MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import optimizers
from keras.layers import Dropout

# %%
train_generator = generator(train_path, train_doc, 30)
val_generator = generator(val_path, val_doc, 30)

# %% [markdown]
# BUILDING MODEL WITH TIMEDISTRIBUTED AND CONV2D

# %%
#write your model here
nb_featuremap = [8,16,32,64]
nb_dense = [128,64,5]
nb_classes = 5
rows = 120   # X 
cols = 120   # Y 
channel = 3  # number of channels in images 3 for color(RGB)
frames=15
batch_size = 10
#model = Sequential()
model1 = Sequential()
model1.add(TimeDistributed(Conv2D(nb_featuremap[0], (3, 3),activation='relu', padding='same'), input_shape=(len(img_idx), image_height, image_width, 3)))


#model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))

model1.add(TimeDistributed(Conv2D(nb_featuremap[1], (3,3),padding='same', activation='relu')))
model1.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model1.add(TimeDistributed(Conv2D(nb_featuremap[2], (3,3),padding='same', activation='relu')))
model1.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model1.add(TimeDistributed(Conv2D(nb_featuremap[3], (2,2),padding='same', activation='relu')))
model1.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model1.add(TimeDistributed(BatchNormalization()))
model1.add(Dropout(0.25))

model1.add(Flatten())

model1.add(Dense(nb_dense[0], activation='relu'))
model1.add(Dropout(0.25))
model1.add(Dense(nb_dense[1], activation='relu'))
model1.add(Dropout(0.25))

## using GRU as the RNN model along with softmax as our last layer.
#model.add(GRU(128, return_sequences=False))
model1.add(Dense(nb_classes, activation='softmax')) # using Softmax as last layer
optimiser = optimizers.Adam(learning_rate=0.0001)
model1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model1.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 15, 100, 100, 8)  224
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 15, 100, 100, 16)  1168
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 15, 50, 50, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 15, 50, 50, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 15, 25, 25, 32)   0
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 15, 25, 25, 64)   8256
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 15, 12, 12, 64)   0
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 15, 12, 12, 64)   256
#  tributed)
#
#  dropout_8 (Dropout)         (None, 15, 12, 12, 64)    0
#
#  flatten_4 (Flatten)         (None, 138240)            0
#
#  dense_12 (Dense)            (None, 128)               17694848
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 17,717,973
# Trainable params: 17,717,845
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
model_name1 = 'model_exp1_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name1):
    os.mkdir(model_name1)
        
filepath = model_name1 + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list1 = [checkpoint, LR]

# %% [markdown]
# FITTING THE MODEL

# %%
history1 = model1.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=15, verbose=1, 
                    callbacks=callbacks_list1, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 30
# Epoch 1/15
# 166/166 [==============================] - ETA: 0s - loss: 1.6448 - categorical_accuracy: 0.3690Source path =  /home/datasets/Project_data/val ; batch size = 30
#
# Epoch 00001: val_loss improved from inf to 1.70860, saving model to model_exp1_2023-02-1214_27_23.083021/model-00001-1.64482-0.36905-1.70860-0.39355.h5
# 166/166 [==============================] - 191s 1s/step - loss: 1.6448 - categorical_accuracy: 0.3690 - val_loss: 1.7086 - val_categorical_accuracy: 0.3935 - lr: 1.0000e-04
# Epoch 2/15
# 166/166 [==============================] - ETA: 0s - loss: 1.2751 - categorical_accuracy: 0.5060
# Epoch 00002: val_loss improved from 1.70860 to 1.28521, saving model to model_exp1_2023-02-1214_27_23.083021/model-00002-1.27511-0.50602-1.28521-0.51200.h5
# 166/166 [==============================] - 80s 485ms/step - loss: 1.2751 - categorical_accuracy: 0.5060 - val_loss: 1.2852 - val_categorical_accuracy: 0.5120 - lr: 1.0000e-04
# Epoch 3/15
# 166/166 [==============================] - ETA: 0s - loss: 1.2273 - categorical_accuracy: 0.5221Epoch 11/15
# 166/166 [==============================] - ETA: 0s - loss: 0.3816 - categorical_accuracy: 0.8675
# Epoch 00011: val_loss did not improve from 0.91238
# 166/166 [==============================] - 93s 559ms/step - loss: 0.3816 - categorical_accuracy: 0.8675 - val_loss: 0.9957 - val_categorical_accuracy: 0.6720 - lr: 5.0000e-05
# Epoch 12/15
# 166/166 [==============================] - ETA: 0s - loss: 0.2602 - categorical_accuracy: 0.9137
# Epoch 00012: val_loss did not improve from 0.91238
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 166/166 [==============================] - 88s 530ms/step - loss: 0.2602 - categorical_accuracy: 0.9137 - val_loss: 1.1581 - val_categorical_accuracy: 0.6040 - lr: 5.0000e-05
# Epoch 13/15
# 166/166 [==============================] - ETA: 0s - loss: 0.2922 - categorical_accuracy: 0.8815
# Epoch 00013: val_loss did not improve from 0.91238
# 166/166 [==============================] - 85s 511ms/step - loss: 0.2922 - categorical_accuracy: 0.8815 - val_loss: 0.9978 - val_categorical_accuracy: 0.6560 - lr: 2.5000e-05
# Epoch 14/15
# 166/166 [==============================] - ETA: 0s - loss: 0.2519 - categorical_accuracy: 0.9116
# Epoch 00014: val_loss improved from 0.91238 to 0.89921, saving model to model_exp1_2023-02-1214_27_23.083021/model-00014-0.25192-0.91165-0.89921-0.70800.h5
# 166/166 [==============================] - 85s 514ms/step - loss: 0.2519 - categorical_accuracy: 0.9116 - val_loss: 0.8992 - val_categorical_accuracy: 0.7080 - lr: 2.5000e-05
# Epoch 15/15
# 166/166 [==============================] - ETA: 0s - loss: 0.2174 - categorical_accuracy: 0.9177
# Epoch 00015: val_loss did not improve from 0.89921
# 166/166 [==============================] - 84s 509ms/step - loss: 0.2174 - categorical_accuracy: 0.9177 - val_loss: 0.9236 - val_categorical_accuracy: 0.6920 - lr: 2.5000e-05

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][15-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][15-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])
    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(15)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

  
plot_history(history1)
# Out:
# **Training Accuracy:** 0.92%
# **Validation Accuracy:** 0.69%

# %% [markdown]
# GETTING TRAINING ACCURACY 0.92% AND VALIDATION ACCURACY 0.69%

# %% [markdown]
# BUILDING MODEL WITH TIMEDISTRIBUTED AND CONV2D WITH GRU

# %%
batch_size = 30

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout,LSTM,Conv3D,Conv2D, MaxPooling3D,MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import optimizers
from keras.layers import Dropout

# %%
train_generator = generator(train_path, train_doc, 6)
val_generator = generator(val_path, val_doc, 6)

# %% [markdown]
# BUILDING THE MODEL

# %%
#write your model here
nb_featuremap = [8,16,32,64]
nb_dense = [128,64,5]
nb_classes = 5
rows = 120   # X 
cols = 120   # Y 
channel = 3  # number of channels in images 3 for color(RGB)
frames=15
# Input
#input_shape=(frames,rows,cols,channel)
batch_size = 10
#model = Sequential()
model23 = Sequential()
model23.add(TimeDistributed(Conv2D(nb_featuremap[0], (3, 3),activation='relu', padding='same'), input_shape=(len(img_idx), image_height, image_width, 3)))


#model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))

model23.add(TimeDistributed(Conv2D(nb_featuremap[1], (3,3),padding='same', activation='relu')))
model23.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model23.add(TimeDistributed(Conv2D(nb_featuremap[2], (3,3),padding='same', activation='relu')))
model23.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model23.add(TimeDistributed(Conv2D(nb_featuremap[3], (2,2),padding='same', activation='relu')))
model23.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model23.add(TimeDistributed(BatchNormalization()))
model23.add(Dropout(0.25))

model23.add(TimeDistributed(Flatten()))

model23.add(Dense(nb_dense[0], activation='relu'))
model23.add(Dropout(0.25))
model23.add(Dense(nb_dense[1], activation='relu'))
model23.add(Dropout(0.25))

## using GRU as the RNN model along with softmax as our last layer.
model23.add(GRU(128, return_sequences=False))
model23.add(Dense(nb_classes, activation='softmax')) # using Softmax as last layer
optimiser = optimizers.Adam(learning_rate=0.0001)
model23.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model23.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_27 (TimeDi  (None, 10, 50, 50, 8)    224
#  stributed)
#
#  time_distributed_28 (TimeDi  (None, 10, 50, 50, 16)   1168
#  stributed)
#
#  time_distributed_29 (TimeDi  (None, 10, 25, 25, 16)   0
#  stributed)
#
#  time_distributed_30 (TimeDi  (None, 10, 25, 25, 32)   4640
#  stributed)
#
#  time_distributed_31 (TimeDi  (None, 10, 12, 12, 32)   0
#  stributed)
#
#  time_distributed_32 (TimeDi  (None, 10, 12, 12, 64)   8256
#  stributed)
#
#  time_distributed_33 (TimeDi  (None, 10, 6, 6, 64)     0
#  stributed)
#
#  time_distributed_34 (TimeDi  (None, 10, 6, 6, 64)     256
#  stributed)
#
#  dropout_11 (Dropout)        (None, 10, 6, 6, 64)      0
#
#  time_distributed_35 (TimeDi  (None, 10, 2304)         0
#  stributed)
#
#  dense_12 (Dense)            (None, 10, 128)           295040
#
#  dropout_12 (Dropout)        (None, 10, 128)           0
#
#  dense_13 (Dense)            (None, 10, 64)            8256
#
#  dropout_13 (Dropout)        (None, 10, 64)            0
#
#  gru_3 (GRU)                 (None, 128)               74496
#
#  dense_14 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 392,981
# Trainable params: 392,853
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
model_name23 = 'model_exp1_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name23):
    os.mkdir(model_name23)
        
filepath = model_name23 + 'model_GRU-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list3= [checkpoint, LR]

# %% [markdown]
# FITTING THE MODEL

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/6)
else:
    steps_per_epoch = (num_train_sequences//6) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/6)
else:
    validation_steps = (num_val_sequences//6) + 1
history23 = model23.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=20, verbose=1, 
                    callbacks=callbacks_list3, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 6
# Epoch 1/20
# 111/111 [==============================] - ETA: 0s - loss: 1.5603 - categorical_accuracy: 0.2866Source path =  /home/datasets/Project_data/val ; batch size = 6
#
# Epoch 00001: val_loss improved from inf to 1.83112, saving model to model_exp1_2023-02-1305_06_54.426715/model_GRU-00001-1.56028-0.28658-1.83112-0.28125.h5
# 111/111 [==============================] - 76s 671ms/step - loss: 1.5603 - categorical_accuracy: 0.2866 - val_loss: 1.8311 - val_categorical_accuracy: 0.2812 - lr: 1.0000e-04
# Epoch 2/20
# 111/111 [==============================] - ETA: 0s - loss: 1.3346 - categorical_accuracy: 0.4084
# Epoch 00002: val_loss improved from 1.83112 to 1.45687, saving model to model_exp1_2023-02-1305_06_54.426715/model_GRU-00002-1.33455-0.40841-1.45687-0.39062.h5
# 111/111 [==============================] - 38s 342ms/step - loss: 1.3346 - categorical_accuracy: 0.4084 - val_loss: 1.4569 - val_categorical_accuracy: 0.3906 - lr: 1.0000e-04
# Epoch 3/20
# 111/111 [==============================] - ETA: 0s - loss: 1.2212 - categorical_accuracy: 0.5195
# Epoch 00003: val_loss improved from 1.45687 to 1.11761, saving model to model_exp1_2023-02-1305_06_54.426715/model_GRU-00003-1.22123-0.51952-1.11761-0.56250.h5
# 111/111 [==============================] - 42s 380ms/step - loss: 1.2212 - categorical_accuracy: 0.5195 - val_loss: 1.1176 - val_categorical_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 4/20
# 111/111 [==============================] - ETA: 0s - loss: 1.0942 - categorical_accuracy: 0.5916
# Epoch 00004: val_loss did not improve from 1.11761
# 111/111 [==============================] - 39s 355ms/step - loss: 1.0942 - categorical_accuracy: 0.5916 - val_loss: 1.1296 - val_categorical_accuracy: 0.5781 - lr: 1.0000e-04
# Epoch 5/20
# 111/111 [==============================] - ETA: 0s - loss: 0.9946 - categorical_accuracy: 0.6126
# Epoch 00005: val_loss improved from 1.11761 to 0.94782, saving model to model_exp1_2023-02-1305_06_54.426715/model_GRU-00005-0.99456-0.61261-0.94782-0.67188.h5
# 111/111 [==============================] - 41s 366ms/step - loss: 0.9946 - categorical_accuracy: 0.6126 - val_loss: 0.9478 - val_categorical_accuracy: 0.6719 - lr: 1.0000e-04
# Epoch 6/20
# 111/111 [==============================] - ETA: 0s - loss: 0.8456 - categorical_accuracy: 0.6907
# Epoch 00006: val_loss did not improve from 0.94782
# 111/111 [==============================] - 40s 359ms/step - loss: 0.8456 - categorical_accuracy: 0.6907 - val_loss: 1.1537 - val_categorical_accuracy: 0.5938 - lr: 1.0000e-04
# Epoch 7/20
# 111/111 [==============================] - ETA: 0s - loss: 0.8134 - categorical_accuracy: 0.7117
# Epoch 00007: val_loss did not improve from 0.94782
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 111/111 [==============================] - 41s 366ms/step - loss: 0.8134 - categorical_accuracy: 0.7117 - val_loss: 1.0663 - val_categorical_accuracy: 0.5469 - lr: 1.0000e-04
# Epoch 8/20
# 111/111 [==============================] - ETA: 0s - loss: 0.6640 - categorical_accuracy: 0.7808
# Epoch 00008: val_loss improved from 0.94782 to 0.94184, saving model to model_exp1_2023-02-1305_06_54.426715/model_GRU-00008-0.66403-0.78078-0.94184-0.54688.h5
# 111/111 [==============================] - 40s 362ms/step - loss: 0.6640 - categorical_accuracy: 0.7808 - val_loss: 0.9418 - val_categorical_accuracy: 0.5469 - lr: 5.0000e-05
# Epoch 9/20
# 111/111 [==============================] - ETA: 0s - loss: 0.6002 - categorical_accuracy: 0.7898
# Epoch 00009: val_loss did not improve from 0.94184
# 111/111 [==============================] - 40s 363ms/step - loss: 0.6002 - categorical_accuracy: 0.7898 - val_loss: 0.9505 - val_categorical_accuracy: 0.5781 - lr: 5.0000e-05
# Epoch 10/20
# 111/111 [==============================] - ETA: 0s - loss: 0.5706 - categorical_accuracy: 0.7748
# Epoch 00010: val_loss improved from 0.94184 to 0.88076, saving model to model_exp1_2023-02-1305_06_54.426715/model_GRU-00010-0.57055-0.77477-0.88076-0.70312.h5
# 111/111 [==============================] - 39s 354ms/step - loss: 0.5706 - categorical_accuracy: 0.7748 - val_loss: 0.8808 - val_categorical_accuracy: 0.7031 - lr: 5.0000e-05
# Epoch 11/20
# 111/111 [==============================] - ETA: 0s - loss: 0.5474 - categorical_accuracy: 0.8138
# Epoch 00011: val_loss did not improve from 0.88076
# 111/111 [==============================] - 40s 363ms/step - loss: 0.5474 - categorical_accuracy: 0.8138 - val_loss: 0.8926 - val_categorical_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 12/20
# 111/111 [==============================] - ETA: 0s - loss: 0.4700 - categorical_accuracy: 0.8619
# Epoch 00012: val_loss did not improve from 0.88076
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 111/111 [==============================] - 39s 354ms/step - loss: 0.4700 - categorical_accuracy: 0.8619 - val_loss: 1.1402 - val_categorical_accuracy: 0.6094 - lr: 5.0000e-05
# Epoch 13/20
# 111/111 [==============================] - ETA: 0s - loss: 0.5239 - categorical_accuracy: 0.8078
# Epoch 00013: val_loss improved from 0.88076 to 0.76926, saving model to model_exp1_2023-02-1305_06_54.426715/model_GRU-00013-0.52390-0.80781-0.76926-0.71875.h5
# 111/111 [==============================] - 41s 367ms/step - loss: 0.5239 - categorical_accuracy: 0.8078 - val_loss: 0.7693 - val_categorical_accuracy: 0.7188 - lr: 2.5000e-05
# Epoch 14/20
# 111/111 [==============================] - ETA: 0s - loss: 0.3926 - categorical_accuracy: 0.8889
# Epoch 00014: val_loss did not improve from 0.76926
# 111/111 [==============================] - 40s 362ms/step - loss: 0.3926 - categorical_accuracy: 0.8889 - val_loss: 0.8124 - val_categorical_accuracy: 0.7344 - lr: 2.5000e-05
# Epoch 15/20
# 111/111 [==============================] - ETA: 0s - loss: 0.4423 - categorical_accuracy: 0.8468
# Epoch 00015: val_loss did not improve from 0.76926
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 111/111 [==============================] - 40s 358ms/step - loss: 0.4423 - categorical_accuracy: 0.8468 - val_loss: 0.9167 - val_categorical_accuracy: 0.6875 - lr: 2.5000e-05
# Epoch 16/20
# 111/111 [==============================] - ETA: 0s - loss: 0.3461 - categorical_accuracy: 0.9039
# Epoch 00016: val_loss did not improve from 0.76926
# 111/111 [==============================] - 41s 368ms/step - loss: 0.3461 - categorical_accuracy: 0.9039 - val_loss: 0.9513 - val_categorical_accuracy: 0.6406 - lr: 1.2500e-05
# Epoch 17/20
# 111/111 [==============================] - ETA: 0s - loss: 0.3658 - categorical_accuracy: 0.8889
# Epoch 00017: val_loss improved from 0.76926 to 0.70162, saving model to model_exp1_2023-02-1305_06_54.426715/model_GRU-00017-0.36584-0.88889-0.70162-0.75000.h5
# 111/111 [==============================] - 39s 353ms/step - loss: 0.3658 - categorical_accuracy: 0.8889 - val_loss: 0.7016 - val_categorical_accuracy: 0.7500 - lr: 1.2500e-05
# Epoch 18/20
# 111/111 [==============================] - ETA: 0s - loss: 0.3268 - categorical_accuracy: 0.9129
# Epoch 00018: val_loss did not improve from 0.70162
# 111/111 [==============================] - 40s 361ms/step - loss: 0.3268 - categorical_accuracy: 0.9129 - val_loss: 1.0259 - val_categorical_accuracy: 0.7188 - lr: 1.2500e-05
# Epoch 19/20
# 111/111 [==============================] - ETA: 0s - loss: 0.3927 - categorical_accuracy: 0.8739
# Epoch 00019: val_loss did not improve from 0.70162
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 111/111 [==============================] - 40s 359ms/step - loss: 0.3927 - categorical_accuracy: 0.8739 - val_loss: 0.7773 - val_categorical_accuracy: 0.6719 - lr: 1.2500e-05
# Epoch 20/20
# 111/111 [==============================] - ETA: 0s - loss: 0.3306 - categorical_accuracy: 0.8919
# Epoch 00020: val_loss did not improve from 0.70162
# 111/111 [==============================] - 41s 368ms/step - loss: 0.3306 - categorical_accuracy: 0.8919 - val_loss: 0.8655 - val_categorical_accuracy: 0.7031 - lr: 6.2500e-06

# %% [markdown]
# PLOTTING THE GRAPH

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][20-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][20-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])
    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(20)

    plt.figure(figsize=(20, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

  
plot_history(history23)
# Out:
# **Training Accuracy:** 0.89%
# **Validation Accuracy:** 0.7%

# %% [markdown]
# GETTING THE TRAINING  ACCURACY OF 0.89% AND VALIDATION ACCURACY 0.7%

# %% [markdown]
# TRANSFER LEARNING WITH RESNET50

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
#write your model here
nb_featuremap = [8,16,32,64]
nb_dense = [128,64,5]
nb_classes = 5
rows = 120   # X 
cols = 120   # Y 
channel = 3  # number of channels in images 3 for color(RGB)
frames=15
# Input
#input_shape=(frames,rows,)

resnet =ResNet50(weights='imagenet', include_top=False)
for layer in resnet.layers:
    layer.trainable=False

model1 = Sequential([TimeDistributed(resnet,input_shape=(len(img_idx), image_height, image_width, 3))])
model1.add(TimeDistributed(Conv2D(nb_featuremap[0], (3, 3),activation='relu', padding='same'), input_shape=(len(img_idx), image_height, image_width, 3)))



#model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))



model1.add(TimeDistributed(BatchNormalization()))
model1.add(TimeDistributed(MaxPooling2D((2, 2))))
model1.add(Dropout(0.25))

model1.add(TimeDistributed(Flatten()))

#model1.add(Dense(nb_dense[0], activation='relu'))
#model1.add(Dense(nb_dense[1], activation='relu'))
#model1.add(Dropout(0.25))

## using GRU as the RNN model along with softmax as our last layer.
model1.add(LSTM(64))
model1.add(Dense(nb_classes, activation='softmax')) # using Softmax as last layer
optimiser = optimizers.Adam(learning_rate=0.0002)
model1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
train_generator = generator(train_path, train_doc, 4)
val_generator = generator(val_path, val_doc, 4)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/4)
else:
    steps_per_epoch = (num_train_sequences//4) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/4)
else:
    validation_steps = (num_val_sequences//4) + 1
history23_transferlearning = model1.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=15, verbose=1, 
                     validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 4
# Epoch 1/15
# 166/166 [==============================] - ETA: 0s - loss: 1.4533 - categorical_accuracy: 0.3786Source path =  /home/datasets/Project_data/val ; batch size = 4
# 166/166 [==============================] - 224s 814ms/step - loss: 1.4533 - categorical_accuracy: 0.3786 - val_loss: 1.2217 - val_categorical_accuracy: 0.5600
# Epoch 2/15
# 166/166 [==============================] - 106s 643ms/step - loss: 1.1648 - categorical_accuracy: 0.5904 - val_loss: 1.2689 - val_categorical_accuracy: 0.4400
# Epoch 3/15
# 166/166 [==============================] - 105s 636ms/step - loss: 1.0343 - categorical_accuracy: 0.6546 - val_loss: 1.0764 - val_categorical_accuracy: 0.6100
# Epoch 4/15
# 166/166 [==============================] - 106s 637ms/step - loss: 0.9127 - categorical_accuracy: 0.6647 - val_loss: 0.9279 - val_categorical_accuracy: 0.6400
# Epoch 5/15
# 166/166 [==============================] - 106s 641ms/step - loss: 0.7260 - categorical_accuracy: 0.7510 - val_loss: 1.1372 - val_categorical_accuracy: 0.5500
# Epoch 6/15
# 166/166 [==============================] - 105s 636ms/step - loss: 0.6541 - categorical_accuracy: 0.7831 - val_loss: 1.1456 - val_categorical_accuracy: 0.5400
# Epoch 7/15
# 166/166 [==============================] - 106s 640ms/step - loss: 0.5247 - categorical_accuracy: 0.8112 - val_loss: 0.8514 - val_categorical_accuracy: 0.6900
# Epoch 8/15
# 166/166 [==============================] - 106s 639ms/step - loss: 0.4260 - categorical_accuracy: 0.8655 - val_loss: 0.7992 - val_categorical_accuracy: 0.7900
# Epoch 9/15
# 166/166 [==============================] - 107s 644ms/step - loss: 0.4131 - categorical_accuracy: 0.8795 - val_loss: 0.8229 - val_categorical_accuracy: 0.6800
# Epoch 10/15
# 166/166 [==============================] - 112s 675ms/step - loss: 0.3756 - categorical_accuracy: 0.8695 - val_loss: 0.7664 - val_categorical_accuracy: 0.7000
# Epoch 11/15
# 166/166 [==============================] - 107s 645ms/step - loss: 0.2371 - categorical_accuracy: 0.9297 - val_loss: 0.7529 - val_categorical_accuracy: 0.7400
# Epoch 12/15
# 166/166 [==============================] - 111s 668ms/step - loss: 0.2155 - categorical_accuracy: 0.9337 - val_loss: 0.7913 - val_categorical_accuracy: 0.7400
# Epoch 13/15
# 166/166 [==============================] - 113s 679ms/step - loss: 0.2364 - categorical_accuracy: 0.9357 - val_loss: 0.8370 - val_categorical_accuracy: 0.6200
# Epoch 14/15
# 166/166 [==============================] - 110s 661ms/step - loss: 0.2387 - categorical_accuracy: 0.9197 - val_loss: 0.9056 - val_categorical_accuracy: 0.6900
# Epoch 15/15
# 166/166 [==============================] - 105s 635ms/step - loss: 0.1992 - categorical_accuracy: 0.9317 - val_loss: 0.9389 - val_categorical_accuracy: 0.7000

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][15-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][15-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])
    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(15)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

  
plot_history(history23_transferlearning)
# Out:
# **Training Accuracy:** 0.93%
# **Validation Accuracy:** 0.7%

# %% [markdown]
#     GETTING TRAINING ACCURACY OF 0.93% nd VALIDATION ACCURACY 0.7%

# %% [markdown]
# CONCLUSION

# %% [markdown]
# FROM THE ABOVE ANALYSIS WILL CHOOSE THE CONV3D AS THE FINAL MODEL COZ IT IS GIVING VALIDATION ACCURACY AS 80%
